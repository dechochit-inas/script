# %% [markdown]
# สรุปเนื้อหาบทเรียนสัปดาห์ที่ 1 (Week 1 Recap) สำหรับใช้บันทึกใน Learning Log (บันทึกการเรียนรู้) ความยาวประมาณ 5 นาที พร้อมโค้ดตัวอย่างสำหรับการเรียนรู้เรื่องการทำ Logging และพื้นฐานภาษา Python ครับ
#
# #📝 บันทึกการเรียนรู้: สรุปบทเรียนสัปดาห์ที่ 1 (Week 1 Recap)
# วิชา: Script Programming
# หัวข้อ: แนะนำภาษา Python, สภาพแวดล้อมการเขียนโปรแกรม และไวยากรณ์พื้นฐาน
#
# #⏱️ นาทีที่ 1: ภาษา Python คืออะไร ทำไมต้องใช้ทำ Scripting?
# Python เป็น ภาษาโปรแกรมระดับสูง (High-level), ประเภท Interpreted และ General-purpose ที่เน้นความอ่านง่ายและเรียบง่ายของโค้ด (ตามปรัชญา Zen of Python เช่น "Beautiful is better than ugly")
#
# บทบาทในงาน Scripting: ไม่ต้องผ่านกระบวนการ Compile สลับซับซ้อน เหมาะมากสำหรับงานอัตโนมัติ (Automation), การจัดการไฟล์, การวิเคราะห์ข้อมูล และโปรแกรมระบบ AI/ML
#
# คุณสมบัติเด่น: ใช้ระบบ Dynamic Typing (ตัวแปรจะเปลี่ยนชนิดข้อมูลตามค่าที่ได้รับโดยอัตโนมัติ) และมีการจัดการหน่วยความจำโดยอัตโนมัติ
#
# #⏱️ นาทีที่ 2: การเตรียมสภาพแวดล้อมและการรันโค้ด
# ในสัปดาห์นี้เราได้เรียนรู้วิธีการรัน Python ผ่านเครื่องมือต่างๆ เช่น Anaconda (ชุดจัดการแพ็กเกจสำหรับ Data Science) และ VS Code (โปรแกรมแก้ไขโค้ดที่ทรงพลัง) รวมถึง Google Colab เราสามารถรันโค้ดได้หลายรูปแบบ:
#
# Interactive Shell (REPL): พิมพ์คำสั่งรันสดๆ ใน Terminal ด้วยคำสั่ง python
#
# Script Files: บันทึกไฟล์นามสกุล .py แล้วสั่งรันผ่าน Terminal:
#
# Bash
# $ python hello.py
# Notebooks: การรันโค้ดเป็นบล็อก (Cells) บนเครื่องมืออย่าง Google Colab
#
# #⏱️ นาทีที่ 3: ไวยากรณ์พื้นฐานและการเยื้องโค้ด (Indentation)
# ความโดดเด่นของ Python คือการบังคับใช้ช่องว่างเพื่อกำหนดขอบเขตของโค้ดแทนการใช้เครื่องหมายปีกกา {}
#
# การเยื้องโค้ด (Indentation): Python ใช้เครื่องหมาย Colon (:) ร่วมกับการเคาะช่องว่าง (นิยมใช้ 4 Spaces) ในการสร้างบล็อกคำสั่ง
#
# Comments: การใส่หมายเหตุเพื่ออธิบายโค้ด จะใช้เครื่องหมาย # สำหรับบรรทัดเดียว หรือเครื่องหมายคำพูด 3 ตัว (''' หรือ """) สำหรับหลายบรรทัด (Docstrings)
#
# Python
# ## นี่คือ Comment แบบบรรทัดเดียว
#
# """
# นี่คือ Comment แบบหลายบรรทัด (Multi-line Comment)
# มักใช้ในการเขียนอธิบายการทำงานของฟังก์ชันหรือโปรแกรมขนาดใหญ่
# """
# print("การเยื้องโค้ดและ Comment ช่วยให้โค้ดสะอาดและอ่านง่ายขึ้น")
# #⏱️ นาทีที่ 4: ตัวแปร (Variables) และชนิดข้อมูลพื้นฐาน
# ตัวแปรเปรียบเสมือนป้ายชื่อที่ใช้ชี้ไปยังข้อมูลที่ถูกเก็บอยู่ในหน่วยความจำ การตั้งชื่อนิยมใช้รูปแบบ snake_case (อักษรพิมพ์เล็กแยกด้วยเครื่องหมายขีดล่าง)
#
# ชนิดข้อมูลพื้นฐานที่สำคัญ:
# Integers (int) และ Floats (float): จำนวนเต็ม และจำนวนจริง (ทศนิยม)
#
# Booleans (bool): ค่าความจริง มีเพียง True หรือ False
#
# Strings (str): ข้อความหรืออักขระที่ครอบด้วยเครื่องหมายอัญประกาศเดี่ยวหรือคู่ (' หรือ ")
#
# ตัวอย่างโค้ด: การประกาศตัวแปรและการตรวจสอบชนิดข้อมูล
# Python
# ## การประกาศตัวแปรและกำหนดค่า
# age = 21                  # int (จำนวนเต็ม)
# gpa = 3.85                # float (ทศนิยม)
# is_enrolled = True        # bool (ค่าความจริง)
# course_name = "Scripting" # str (ข้อความ)
#
# ## การตรวจสอบชนิดข้อมูลด้วยฟังก์ชัน type()
# print(type(age))          # ผลลัพธ์: <class 'int'>
# print(type(gpa))          # ผลลัพธ์: <class 'float'>
# print(type(course_name))  # ผลลัพธ์: <class 'str'>
# #⏱️ นาทีที่ 5: การรับค่าและการแสดงผล (Input & Output)
# เพื่อให้สคริปต์ทำงานได้อย่างยืดหยุ่น เราจำเป็นต้องมีการรับข้อมูลจากผู้ใช้และจัดฟอร์แมตการแสดงผล
#
# จุดสำคัญที่ต้องบันทึก: ฟังก์ชัน input() จะส่งคืนค่ากลับมาเป็นข้อความ (str) เสมอ หากต้องการนำไปคำนวณทางคณิตศาสตร์ จะต้องนำมาแปลงชนิดข้อมูล (Casting) เสียก่อน ด้วยฟังก์ชัน int() หรือ float()
#
# ตัวอย่างโค้ด: โปรแกรมรับค่าและแปลงข้อมูล (พร้อมแนวคิดพื้นฐานของ Learning Logging)
# Python
# ## 1. การรับข้อมูลประเภทข้อความ
# user_name = input("กรุณากรอกชื่อของคุณ: ")
#
# ## 2. การรับข้อมูลตัวเลขและทำการแปลงประเภท (Type Casting)
# เนื่องจาก input() ได้ค่าเป็นข้อความ จึงต้องแปลงเป็น float เพื่อใช้คำนวณ
# raw_hours = input("สัปดาห์นี้คุณใช้เวลาเรียน Python ไปกี่ชั่วโมง? ")
# hours_studying = float(raw_hours)
#
# ## 3. การคำนวณทางคณิตศาสตร์
# daily_average = hours_studying / 7
#
# ## 4. การแสดงผลข้อมูลออกทางหน้าจอ (Console Output)
# print(f"สวัสดีคุณ {user_name}!")
# print(f"เฉลี่ยแล้วคุณเรียนวันละ: {daily_average:.2f} ชั่วโมง")
# 💡 สิ่งที่ได้เรียนรู้ (Core Takeaways สำหรับใส่ท้าย Log)
# "หัวใจสำคัญของการเขียนสคริปต์ด้วย Python ในสัปดาห์แรกคือ ความเข้าใจเรื่อง ชนิดข้อมูล (Data Types) และการส่งต่อข้อมูลผ่านคำสั่งรับ-แสดงผล ปัญหาทั่วไปที่มักเจอคือข้อผิดพลาดประเภท TypeError เมื่อเราเผลอนำข้อมูลที่ได้จาก input() (ซึ่งเป็นสตริง) ไปคำนวณเลขโดยตรง ดังนั้นการทำ Type Conversion (Casting) จึงเป็นทักษะพื้นฐานที่ต้องใช้อยู่เสมอในสัปดาห์ถัดๆ ไป"

# %% [markdown]
# #📝 บันทึกการเรียนรู้: สรุปบทเรียนสัปดาห์ที่ 1 (Week 1 Recap)
# วิชา: Script Programming
# หัวข้อ: แนะนำภาษา Python, สภาพแวดล้อมการเขียนโปรแกรม และไวยากรณ์พื้นฐาน
#
# ##⏱️ นาทีที่ 1: ภาษา Python คืออะไร ทำไมต้องใช้ทำ Scripting?
# Python เป็น ภาษาโปรแกรมระดับสูง (High-level), ประเภท Interpreted และ General-purpose ที่เน้นความอ่านง่ายและเรียบง่ายของโค้ด (ตามปรัชญา Zen of Python เช่น "Beautiful is better than ugly")
#
# บทบาทในงาน Scripting: ไม่ต้องผ่านกระบวนการ Compile สลับซับซ้อน เหมาะมากสำหรับงานอัตโนมัติ (Automation), การจัดการไฟล์, การวิเคราะห์ข้อมูล และโปรแกรมระบบ AI/ML
#
# คุณสมบัติเด่น: ใช้ระบบ Dynamic Typing (ตัวแปรจะเปลี่ยนชนิดข้อมูลตามค่าที่ได้รับโดยอัตโนมัติ) และมีการจัดการหน่วยความจำโดยอัตโนมัติ
#
# ##⏱️ นาทีที่ 2: การเตรียมสภาพแวดล้อมและการรันโค้ด
# ในสัปดาห์นี้เราได้เรียนรู้วิธีการรัน Python ผ่านเครื่องมือต่างๆ เช่น Anaconda (ชุดจัดการแพ็กเกจสำหรับ Data Science) และ VS Code (โปรแกรมแก้ไขโค้ดที่ทรงพลัง) รวมถึง Google Colab เราสามารถรันโค้ดได้หลายรูปแบบ:
#
# Interactive Shell (REPL): พิมพ์คำสั่งรันสดๆ ใน Terminal ด้วยคำสั่ง python
#
# Script Files: บันทึกไฟล์นามสกุล .py แล้วสั่งรันผ่าน Terminal
# Bash
# $ python hello.py
# Notebooks: การรันโค้ดเป็นบล็อก (Cells) บนเครื่องมืออย่าง Google Colab
#
# ##⏱️ นาทีที่ 3: ไวยากรณ์พื้นฐานและการเยื้องโค้ด (Indentation)
# ความโดดเด่นของ Python คือการบังคับใช้ช่องว่างเพื่อกำหนดขอบเขตของโค้ดแทนการใช้เครื่องหมายปีกกา {}
#
# การเยื้องโค้ด (Indentation): Python ใช้เครื่องหมาย Colon (:) ร่วมกับการเคาะช่องว่าง (นิยมใช้ 4 Spaces) ในการสร้างบล็อกคำสั่ง
#
# Comments: การใส่หมายเหตุเพื่ออธิบายโค้ด จะใช้เครื่องหมาย # สำหรับบรรทัดเดียว หรือเครื่องหมายคำพูด 3 ตัว (''' หรือ """) สำหรับหลายบรรทัด (Docstrings)

# %%
# นี่คือ Comment แบบบรรทัดเดียว

"""
นี่คือ Comment แบบหลายบรรทัด (Multi-line Comment)
มักใช้ในการเขียนอธิบายการทำงานของฟังก์ชันหรือโปรแกรมขนาดใหญ่
"""
print("การเยื้องโค้ดและ Comment ช่วยให้โค้ดสะอาดและอ่านง่ายขึ้น")
# Out:
# การเยื้องโค้ดและ Comment ช่วยให้โค้ดสะอาดและอ่านง่ายขึ้น

# %% [markdown]
# ##⏱️ นาทีที่ 4: ตัวแปร (Variables) และชนิดข้อมูลพื้นฐาน
# ตัวแปรเปรียบเสมือนป้ายชื่อที่ใช้ชี้ไปยังข้อมูลที่ถูกเก็บอยู่ในหน่วยความจำ การตั้งชื่อนิยมใช้รูปแบบ snake_case (อักษรพิมพ์เล็กแยกด้วยเครื่องหมายขีดล่าง)
#
# ชนิดข้อมูลพื้นฐานที่สำคัญ:
# Integers (int) และ Floats (float): จำนวนเต็ม และจำนวนจริง (ทศนิยม)
#
# Booleans (bool): ค่าความจริง มีเพียง True หรือ False
#
# Strings (str): ข้อความหรืออักขระที่ครอบด้วยเครื่องหมายอัญประกาศเดี่ยวหรือคู่ (' หรือ ")
#
# ตัวอย่างโค้ด: การประกาศตัวแปรและการตรวจสอบชนิดข้อมูล

# %%
# การประกาศตัวแปรและกำหนดค่า
age = 21                  # int (จำนวนเต็ม)
gpa = 3.85                # float (ทศนิยม)
is_enrolled = True        # bool (ค่าความจริง)
course_name = "Scripting" # str (ข้อความ)

# การตรวจสอบชนิดข้อมูลด้วยฟังก์ชัน type()
print(type(age))          # ผลลัพธ์: <class 'int'>
print(type(gpa))          # ผลลัพธ์: <class 'float'>
print(type(course_name))  # ผลลัพธ์: <class 'str'>
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %% [markdown]
# ##⏱️ นาทีที่ 5: การรับค่าและการแสดงผล (Input & Output)
# เพื่อให้สคริปต์ทำงานได้อย่างยืดหยุ่น เราจำเป็นต้องมีการรับข้อมูลจากผู้ใช้และจัดฟอร์แมตการแสดงผล
#
# จุดสำคัญที่ต้องบันทึก: ฟังก์ชัน input() จะส่งคืนค่ากลับมาเป็นข้อความ (str) เสมอ หากต้องการนำไปคำนวณทางคณิตศาสตร์ จะต้องนำมาแปลงชนิดข้อมูล (Casting) เสียก่อน ด้วยฟังก์ชัน int() หรือ float()
#
# ตัวอย่างโค้ด: โปรแกรมรับค่าและแปลงข้อมูล (พร้อมแนวคิดพื้นฐานของ Learning Logging)

# %%
# 1. การรับข้อมูลประเภทข้อความ
user_name = input("กรุณากรอกชื่อของคุณ: ")

# 2. การรับข้อมูลตัวเลขและทำการแปลงประเภท (Type Casting)
# เนื่องจาก input() ได้ค่าเป็นข้อความ จึงต้องแปลงเป็น float เพื่อใช้คำนวณ
raw_hours = input("สัปดาห์นี้คุณใช้เวลาเรียน Python ไปกี่ชั่วโมง? ")
hours_studying = float(raw_hours)

# 3. การคำนวณทางคณิตศาสตร์
daily_average = hours_studying / 7

# 4. การแสดงผลข้อมูลออกทางหน้าจอ (Console Output)
print(f"สวัสดีคุณ {user_name}!")
print(f"เฉลี่ยแล้วคุณเรียนวันละ: {daily_average:.2f} ชั่วโมง")
# Out:
# กรุณากรอกชื่อของคุณ: 4
# สัปดาห์นี้คุณใช้เวลาเรียน Python ไปกี่ชั่วโมง? 4
# สวัสดีคุณ 4!
# เฉลี่ยแล้วคุณเรียนวันละ: 0.57 ชั่วโมง

# %% [markdown]
# ##💡 สิ่งที่ได้เรียนรู้ (Core Takeaways สำหรับใส่ท้าย Log)
# "หัวใจสำคัญของการเขียนสคริปต์ด้วย Python ในสัปดาห์แรกคือ ความเข้าใจเรื่อง ชนิดข้อมูล (Data Types) และการส่งต่อข้อมูลผ่านคำสั่งรับ-แสดงผล ปัญหาทั่วไปที่มักเจอคือข้อผิดพลาดประเภท TypeError เมื่อเราเผลอนำข้อมูลที่ได้จาก input() (ซึ่งเป็นสตริง) ไปคำนวณเลขโดยตรง ดังนั้นการทำ Type Conversion (Casting) จึงเป็นทักษะพื้นฐานที่ต้องใช้อยู่เสมอในสัปดาห์ถัดๆ ไป"
